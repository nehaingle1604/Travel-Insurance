# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\DIVYA\Downloads\Travell Insurance Data.xlsx")

# %%
df
# Out:
#       Agency    Agency Type Distribution Channel        Product Name Claim  \
# 0        CBH  Travel Agency              Offline  Comprehensive Plan    No
# 1        CBH  Travel Agency              Offline  Comprehensive Plan    No
# 2        JZI       Airlines               Online          Value Plan    No
# 3        JZI       Airlines               Online          Basic Plan    No
# 4        KML  Travel Agency               Online        Premier Plan    No
# ...      ...            ...                  ...                 ...   ...
# 18214    JZI       Airlines               Online          Basic Plan    No
# 18215    JZI       Airlines               Online          Basic Plan    No
# 18216    JZI       Airlines               Online          Basic Plan    No
# 18217    JZI       Airlines               Online          Basic Plan    No
# 18218    JZI       Airlines               Online          Basic Plan    No
#
#        Duration    Destination  Net Sales  Commision (in value) Gender  Age
# 0           186       MALAYSIA      -29.0                  9.57      F   81
# 1           186       MALAYSIA      -29.0                  9.57      F   71
# 2            66  UNITED STATES     -121.0                 42.35      F   44
# 3             1       MALAYSIA      -18.0                  6.30      M   47
# 4            53         NORWAY     -130.0                 49.40      F   48
# ...         ...            ...        ...                   ...    ...  ...
# 18214       111          JAPAN       35.0                 12.25      M   31
# 18215        58          CHINA       40.0                 14.00      F   40
# 18216         2       MALAYSIA       18.0                  6.30      M   57
# 18217         3       VIET NAM       18.0                  6.30      M   63
# 18218        22      HONG KONG       26.0                  9.10      F   35
#
# [18219 rows x 11 columns]

# %% [markdown]
# ### EDA & Data Preprocessing

# %%
df.head()
# Out:
#   Agency    Agency Type Distribution Channel        Product Name Claim  \
# 0    CBH  Travel Agency              Offline  Comprehensive Plan    No
# 1    CBH  Travel Agency              Offline  Comprehensive Plan    No
# 2    JZI       Airlines               Online          Value Plan    No
# 3    JZI       Airlines               Online          Basic Plan    No
# 4    KML  Travel Agency               Online        Premier Plan    No
#
#    Duration    Destination  Net Sales  Commision (in value) Gender  Age
# 0       186       MALAYSIA      -29.0                  9.57      F   81
# 1       186       MALAYSIA      -29.0                  9.57      F   71
# 2        66  UNITED STATES     -121.0                 42.35      F   44
# 3         1       MALAYSIA      -18.0                  6.30      M   47
# 4        53         NORWAY     -130.0                 49.40      F   48

# %%
df.shape
# Out:
# (18219, 11)

# %%
df.columns
# Out:
# Index(['Agency', 'Agency Type', 'Distribution Channel', 'Product Name',
#        'Claim', 'Duration', 'Destination', 'Net Sales', 'Commision (in value)',
#        'Gender', 'Age'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age
# count  18219.000000  18219.000000          18219.000000  18219.000000
# mean      68.708491     57.488890             18.480432     44.785444
# std      112.977561     73.884899             24.963075     20.894323
# min       -2.000000   -389.000000              0.000000      0.000000
# 25%        9.000000     22.000000              6.750000     31.000000
# 50%       21.000000     30.000000              9.750000     40.000000
# 75%       57.000000     54.500000             16.750000     52.000000
# max      740.000000    810.000000            283.500000    118.000000

# %%
df.isnull().sum()
# Out:
# Agency                  0
# Agency Type             0
# Distribution Channel    0
# Product Name            0
# Claim                   0
# Duration                0
# Destination             0
# Net Sales               0
# Commision (in value)    0
# Gender                  0
# Age                     0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Destination'].nunique()
# Out:
# 82

# %%
df['Destination'].unique()
# Out:
# array(['MALAYSIA', 'UNITED STATES', 'NORWAY', 'SINGAPORE', 'INDIA',
#        'BRUNEI DARUSSALAM', 'AUSTRALIA', 'INDONESIA', 'THAILAND', 'CHINA',
#        'PHILIPPINES', 'HONG KONG', 'VIET NAM', 'CAMBODIA', 'AUSTRIA',
#        'MYANMAR', 'JAPAN', 'TAIWAN, PROVINCE OF CHINA', 'SRI LANKA',
#        'UNITED KINGDOM', 'FRANCE', 'GERMANY', 'NETHERLANDS', 'MACAO',
#        'KOREA, REPUBLIC OF', 'UNITED ARAB EMIRATES', 'DENMARK',
#        "LAO PEOPLE'S DEMOCRATIC REPUBLIC", 'ITALY', 'OMAN', 'NEW ZEALAND',
#        'FIJI', 'POLAND', 'NEPAL', 'SPAIN', 'CANADA', 'BRAZIL', 'PORTUGAL',
#        'IRELAND', 'NEW CALEDONIA', 'FINLAND', 'SAUDI ARABIA', 'JORDAN',
#        'SWEDEN', 'GUINEA', 'TURKEY', 'BANGLADESH', 'MONGOLIA',
#        'AZERBAIJAN', 'PAKISTAN', 'MOROCCO', 'SWITZERLAND', 'LITHUANIA',
#        'MALI', 'BELGIUM', 'CZECH REPUBLIC', 'HUNGARY', 'PAPUA NEW GUINEA',
#        'BAHRAIN', 'KENYA', 'MAURITIUS', 'CYPRUS', 'ANGOLA', 'BELARUS',
#        'ESTONIA', 'ARGENTINA', 'NAMIBIA', 'BULGARIA', 'PERU', 'QATAR',
#        'ISRAEL', 'TURKMENISTAN', 'EGYPT', 'BHUTAN', 'MEXICO',
#        'IRAN, ISLAMIC REPUBLIC OF', 'UZBEKISTAN', 'RUSSIAN FEDERATION',
#        'FRENCH POLYNESIA', 'MALDIVES', 'SOUTH AFRICA', 'CROATIA'],
#       dtype=object)

# %%
df['Product Name'].nunique()
# Out:
# 22

# %%
df['Product Name'].unique()
# Out:
# array(['Comprehensive Plan', 'Value Plan', 'Basic Plan', 'Premier Plan',
#        'Bronze Plan', 'Silver Plan', 'Annual Silver Plan', '24 Protect',
#        'Gold Plan', 'Annual Gold Plan', 'Rental Vehicle Excess Insurance',
#        'Single Trip Travel Protect Silver',
#        'Individual Comprehensive Plan',
#        'Spouse or Parents Comprehensive Plan',
#        'Annual Travel Protect Silver',
#        'Single Trip Travel Protect Platinum',
#        'Annual Travel Protect Gold', 'Single Trip Travel Protect Gold',
#        'Annual Travel Protect Platinum', 'Child Comprehensive Plan',
#        'Travel Cruise Protect', 'Travel Cruise Protect Family'],
#       dtype=object)

# %%
df['Agency'].nunique()
# Out:
# 14

# %%
df['Agency'].unique()
# Out:
# array(['CBH', 'JZI', 'KML', 'C2B', 'JWT', 'RAB', 'ART', 'CSR', 'CCR',
#        'ADM', 'CWT', 'LWC', 'TTW', 'TST'], dtype=object)

# %%
df['Agency Type'].nunique()
# Out:
# 2

# %%
df['Agency Type'].unique()
# Out:
# array(['Travel Agency', 'Airlines'], dtype=object)

# %%
sns.countplot(data=df, x='Claim')
# Out:
# <AxesSubplot:xlabel='Claim', ylabel='count'>

# %%
sns.countplot(x = 'Gender',data = df,hue = 'Claim')
plt.show()

# %%
sns.countplot(x = 'Agency Type',data = df,hue = 'Claim')
plt.show()

# %%
sns.countplot(x = 'Distribution Channel',data = df,hue = 'Claim')
plt.show()

# %%
sns.distplot(df['Age'])
plt.show()
# Out:
# C:\Users\DIVYA\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Duration'])
plt.show()
# Out:
# C:\Users\DIVYA\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df,hue="Claim")

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(7,7), dpi=100)
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df.corr()
# Out:
#                       Duration  Net Sales  Commision (in value)       Age
# Duration              1.000000   0.795479              0.727757 -0.059720
# Net Sales             0.795479   1.000000              0.838352 -0.029989
# Commision (in value)  0.727757   0.838352              1.000000  0.008537
# Age                  -0.059720  -0.029989              0.008537  1.000000

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
df['Agency'] = label_encoder.fit_transform(df['Agency'])
df['Agency Type'] = label_encoder.fit_transform(df['Agency Type'])
df['Distribution Channel'] = label_encoder.fit_transform(df['Distribution Channel'])
df['Product Name'] = label_encoder.fit_transform(df['Product Name'])
df['Destination'] = label_encoder.fit_transform(df['Destination'])
df['Claim'] = label_encoder.fit_transform(df['Claim'])

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
from scipy.stats import zscore

# %%
df[(zscore(df['Agency'])>3)|(zscore(df['Agency'])<-3)]
# Out:
# Empty DataFrame
# Columns: [Agency, Agency Type, Distribution Channel, Product Name, Claim, Duration, Destination, Net Sales, Commision (in value), Age, Gender_M]
# Index: []

# %%
df[(zscore(df['Agency Type'])>3)|(zscore(df['Agency Type'])<-3)]
# Out:
# Empty DataFrame
# Columns: [Agency, Agency Type, Distribution Channel, Product Name, Claim, Duration, Destination, Net Sales, Commision (in value), Age, Gender_M]
# Index: []

# %%
df[(zscore(df['Distribution Channel'])>3)|(zscore(df['Distribution Channel'])<-3)]
# Out:
#        Agency  Agency Type  Distribution Channel  Product Name  Claim  \
# 0           3            1                     0             9      0
# 1           3            1                     0             9      0
# 89          5            1                     0             9      0
# 90          5            1                     0             9      0
# 91          4            1                     0             9      0
# ...       ...          ...                   ...           ...    ...
# 18080      12            1                     0            19      0
# 18081      12            1                     0            19      0
# 18082      12            1                     0            19      0
# 18083      12            1                     0            19      0
# 18084      12            1                     0            19      0
#
#        Duration  Destination  Net Sales  Commision (in value)  Age  Gender_M
# 0           186           43      -29.0                  9.57   81         0
# 1           186           43      -29.0                  9.57   71         0
# 89           92           43       29.0                  9.57   72         0
# 90           92           43       29.0                  9.57   77         0
# 91            5           43       29.0                  9.57  118         1
# ...         ...          ...        ...                   ...  ...       ...
# 18080         8           74       30.0                 10.50   61         0
# 18081         8           74       30.0                 10.50   61         1
# 18082         8           74       30.0                 10.50   59         0
# 18083         8           74       30.0                 10.50   51         1
# 18084         8           74       30.0                 10.50   50         0
#
# [1013 rows x 11 columns]

# %%
df[(zscore(df['Distribution Channel'])>3)|(zscore(df['Distribution Channel'])<-3)]
# Out:
#        Agency  Agency Type  Distribution Channel  Product Name  Claim  \
# 0           3            1                     0             9      0
# 1           3            1                     0             9      0
# 89          5            1                     0             9      0
# 90          5            1                     0             9      0
# 91          4            1                     0             9      0
# ...       ...          ...                   ...           ...    ...
# 18080      12            1                     0            19      0
# 18081      12            1                     0            19      0
# 18082      12            1                     0            19      0
# 18083      12            1                     0            19      0
# 18084      12            1                     0            19      0
#
#        Duration  Destination  Net Sales  Commision (in value)  Age  Gender_M
# 0           186           43      -29.0                  9.57   81         0
# 1           186           43      -29.0                  9.57   71         0
# 89           92           43       29.0                  9.57   72         0
# 90           92           43       29.0                  9.57   77         0
# 91            5           43       29.0                  9.57  118         1
# ...         ...          ...        ...                   ...  ...       ...
# 18080         8           74       30.0                 10.50   61         0
# 18081         8           74       30.0                 10.50   61         1
# 18082         8           74       30.0                 10.50   59         0
# 18083         8           74       30.0                 10.50   51         1
# 18084         8           74       30.0                 10.50   50         0
#
# [1013 rows x 11 columns]

# %%
df[(zscore(df['Commision (in value)'])>3)|(zscore(df['Commision (in value)'])<-3)]
# Out:
#        Agency  Agency Type  Distribution Channel  Product Name  Claim  \
# 10          2            0                     1             2      0
# 103         2            0                     1             7      0
# 116         2            0                     1             1      0
# 158         2            0                     1             1      0
# 391         2            0                     1             7      0
# ...       ...          ...                   ...           ...    ...
# 18039       2            0                     1            10      0
# 18153       2            0                     1             1      0
# 18187       2            0                     1            14      0
# 18192       2            0                     1            14      0
# 18196       2            0                     1             2      0
#
#        Duration  Destination  Net Sales  Commision (in value)  Age  Gender_M
# 10          364           67     389.00                 97.25   30         0
# 103         179           67     682.00                170.50   25         1
# 116         369           67     389.35                 97.34   42         1
# 158         368           67     389.35                 97.34   50         1
# 391         140           67     538.00                134.50   23         0
# ...         ...          ...        ...                   ...  ...       ...
# 18039       185           67     491.50                122.88   23         0
# 18153       364           67     399.60                 99.90   29         1
# 18187       237           67     482.00                120.50   24         1
# 18192       209           67     388.80                 97.20   32         0
# 18196       365           67     382.00                 95.50   30         0
#
# [379 rows x 11 columns]

# %%
df[(zscore(df['Age'])>3)|(zscore(df['Age'])<-3)]
# Out:
#        Agency  Agency Type  Distribution Channel  Product Name  Claim  \
# 11          7            0                     1            21      0
# 31          7            0                     1            21      0
# 62          7            0                     1            21      0
# 91          4            1                     0             9      0
# 92          4            1                     0             9      0
# ...       ...          ...                   ...           ...    ...
# 18052       7            0                     1            21      0
# 18085       1            0                     1            21      0
# 18137       1            0                     1            21      0
# 18154       7            0                     1            21      0
# 18155       7            0                     1            21      0
#
#        Duration  Destination  Net Sales  Commision (in value)  Age  Gender_M
# 11           11           30       50.0                 20.00  118         1
# 31            4           30       62.0                 24.80  118         0
# 62           16           30       50.0                 20.00  118         1
# 91            5           43       29.0                  9.57  118         1
# 92            5           43       29.0                  9.57  118         0
# ...         ...          ...        ...                   ...  ...       ...
# 18052         2           30       31.0                 12.40  118         1
# 18085        14           24       59.0                 20.65  118         1
# 18137        42           28       61.0                 21.35  118         1
# 18154        21           30       39.0                 15.60  118         0
# 18155        49           30       31.0                 12.40  118         1
#
# [841 rows x 11 columns]

# %%
# Declare X & Y

# %%
x = df.drop('Claim', axis=1)
y = df['Claim']

# %%
y.value_counts()
# Out:
# 0    17580
# 1      639
# Name: Claim, dtype: int64

# %%
#Data splitting into training & testing

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
x_train.shape, x_test.shape
# Out:
# ((12753, 10), (5466, 10))

# %%
from imblearn.combine import SMOTETomek

# %%
smpl = SMOTETomek()

# %%
x_train_os, y_train_os = smpl.fit_resample(x_train, y_train)

# %%
y_train_os.value_counts()
# Out:
# 0    12115
# 1    12115
# Name: Claim, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler

# %%
transform = ColumnTransformer(transformers=[
    ('c1', RobustScaler(),['Distribution Channel']),
    ('c2',RobustScaler(),['Net Sales']),
    ('c3',RobustScaler(),['Commision (in value)']),
    ('c4',RobustScaler(),['Age']),
],remainder = 'passthrough')

# %%
x_train_scl = transform.fit_transform(x_train_os)
x_test_scl = transform.transform(x_test)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()

# %%
lor_mdl = lor.fit(x_train_scl, y_train_os)
lor_mdl
# Out:
# C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lor_y_pred = lor_mdl.predict(x_test_scl)
lor_y_pred
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, roc_curve, roc_auc_score

# %%
accuracy_score_lor = accuracy_score(lor_y_pred, y_test)
accuracy_score_lor
# Out:
# 0.6798390047566777

# %%
cm = confusion_matrix(lor_y_pred, y_test)

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
report = classification_report(lor_y_pred, y_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.98      0.80      3671
#            1       0.63      0.06      0.11      1795
#
#     accuracy                           0.68      5466
#    macro avg       0.66      0.52      0.46      5466
# weighted avg       0.67      0.68      0.58      5466

# %%
fpr, tpr, _ = (roc_curve(lor_y_pred, y_test))

# %%
plt.plot(fpr,tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

# %%
dt_mdl = dt.fit(x_train_scl, y_train_os)
dt_mdl
# Out:
# DecisionTreeClassifier()

# %%
dt_y_pred = dt_mdl.predict(x_test_scl)
dt_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score_dt = accuracy_score(dt_y_pred, y_test)
accuracy_score_dt
# Out:
# 0.8900475667764361

# %%
cm = confusion_matrix(dt_y_pred, y_test)

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(dt_y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      4990
#            1       0.13      0.05      0.07       476
#
#     accuracy                           0.89      5466
#    macro avg       0.52      0.51      0.50      5466
# weighted avg       0.85      0.89      0.87      5466

# %%
fpr, tpr, _ = roc_curve(dt_y_pred, y_test)

# %%
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# #### Tuning

# %%
from sklearn.model_selection import GridSearchCV
tun_dt = [{'criterion':['gini', 'entropy'], 'max_depth':range(1,10), 'min_samples_split': range(1,30)}]
gs_dt = GridSearchCV(DecisionTreeClassifier(), tun_dt, scoring = 'accuracy', cv = 10 )

# %%
gs_dt.fit(x_train_scl, y_train_os)
# Out:
# C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 180 fits failed out of a total of 5220.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users
#  0.82195625        nan 0.83173752 0.8319026  0.83182006 0.83173752
#  0.83182006 0.8319026  0.83182006 0.83206768 0.8319026  0.83169624
#  0.83173752 0.83144862 0.83144862 0.83107718 0.83111845 0.83115972
#  0.83107718 0.83099463 0.83095336 0.83082955 0.83087082 0.83099463
#  0.83087082 0.83062319 0.83045811 0.8303343  0.83029303 0.83016921]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': range(1, 10),
#                           'min_samples_split': range(1, 30)}],
#              scoring='accuracy')

# %%
gs_dt.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 9, 'min_samples_split': 12}

# %%
tune_dt = gs_dt.best_score_
tune_dt
# Out:
# 0.8386710689228231

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rmf = RandomForestClassifier()

# %%
rmf_mdl = rmf.fit(x_train_scl, y_train_os)
rmf_mdl
# Out:
# RandomForestClassifier()

# %%
rmf_y_pred = rmf_mdl.predict(x_test_scl)
rmf_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score_rmf = accuracy_score(rmf_y_pred, y_test)
accuracy_score_rmf
# Out:
# 0.9103549213318698

# %%
cm = confusion_matrix(rmf_y_pred, y_test)

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(rmf_y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      5093
#            1       0.15      0.07      0.10       373
#
#     accuracy                           0.91      5466
#    macro avg       0.54      0.52      0.52      5466
# weighted avg       0.88      0.91      0.89      5466

# %%
fpr, tpr, _ = roc_curve(rmf_y_pred, y_test)

# %%
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# #### Tuning

# %%
rf_tun =  [{'criterion':['gini', 'entropy'], 'max_depth':[5,10,15], 'min_samples_split': range(1,30), 'n_estimators':range(1,10)}]
gs_rf = GridSearchCV(RandomForestClassifier(), rf_tun, scoring='accuracy', cv =10)

# %%
gs_rf.fit(x_train_scl, y_train_os)
# Out:
# C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 540 fits failed out of a total of 15660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 540 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\joblib\parallel.py", line 1855, in __call__
#     return output if self.return_generator else list(output)
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\joblib\parallel.py", line 1784, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 250, in fit
#     raise ValueError(
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\DIVYA\anaconda\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan ... 0.88423442 0.88675196 0.8886917 ]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': [5, 10, 15],
#                           'min_samples_split': range(1, 30),
#                           'n_estimators': range(1, 10)}],
#              scoring='accuracy')

# %%
gs_rf.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 15,
#  'min_samples_split': 2,
#  'n_estimators': 9}

# %%
tune_rmf = gs_rf.best_score_
tune_rmf
# Out:
# 0.9053239785390013

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC
svc = SVC()

# %%
svc_mdl = svc.fit(x_train_scl, y_train_os)
svc_mdl
# Out:
# SVC()

# %%
svc_y_pred = svc_mdl.predict(x_test_scl)
svc_y_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %%
accuracy_score_svc = accuracy_score(svc_y_pred, y_test)
accuracy_score_svc
# Out:
# 0.521770947676546

# %%
cm = confusion_matrix(svc_y_pred, y_test)

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(svc_y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.99      0.67      2731
#            1       0.86      0.05      0.10      2735
#
#     accuracy                           0.52      5466
#    macro avg       0.68      0.52      0.39      5466
# weighted avg       0.68      0.52      0.39      5466

# %%
fpr, tpr, _ = roc_curve(svc_y_pred, y_test)

# %%
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb_mdl = nb.fit(x_train_scl, y_train_os)
nb_mdl
# Out:
# GaussianNB()

# %%
nb_y_pred = nb_mdl.predict(x_test_scl)
nb_y_pred
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
accuracy_score_nb = accuracy_score(nb_y_pred, y_test)
accuracy_score_nb
# Out:
# 0.5852542993047932

# %%
cm = confusion_matrix(nb_y_pred, y_test)

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(nb_y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.99      0.73      3098
#            1       0.80      0.06      0.11      2368
#
#     accuracy                           0.59      5466
#    macro avg       0.69      0.52      0.42      5466
# weighted avg       0.67      0.59      0.46      5466

# %%
fpr, tpr, _ = roc_curve(nb_y_pred, y_test)

# %%
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

# %%
knn_mdl = nb.fit(x_train_scl, y_train_os)
knn_mdl
# Out:
# GaussianNB()

# %%
knn_y_pred = nb_mdl.predict(x_test_scl)
knn_y_pred
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
accuracy_score_knn = accuracy_score(nb_y_pred, y_test)
accuracy_score_knn
# Out:
# 0.5852542993047932

# %%
cm = confusion_matrix(nb_y_pred, y_test)

# %%
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(nb_y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.99      0.73      3098
#            1       0.80      0.06      0.11      2368
#
#     accuracy                           0.59      5466
#    macro avg       0.69      0.52      0.42      5466
# weighted avg       0.67      0.59      0.46      5466

# %%
fpr, tpr, _ = roc_curve(nb_y_pred, y_test)

# %%
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ### Accuracy of all Algorithms

# %%
models = pd.DataFrame({
    "Model": ["Logistic Regression",
              "Decision Tree",
              "Tune Decision Tree",
              "Random Forest",
              "Tune Random Forest",
              "SVM",
              "Naive Bayes",
              "KNN"],
    "Accuracy score": [accuracy_score_lor,accuracy_score_dt,tune_dt, accuracy_score_rmf, tune_rmf,
                       accuracy_score_svc, accuracy_score_nb, accuracy_score_knn]
})

print(models)
# Out:
#                  Model  Accuracy score
# 0  Logistic Regression        0.679839
# 1        Decision Tree        0.890048
# 2   Tune Decision Tree        0.838671
# 3        Random Forest        0.910355
# 4   Tune Random Forest        0.905324
# 5                  SVM        0.521771
# 6          Naive Bayes        0.585254
# 7                  KNN        0.585254

# %%
models.sort_values(by="Accuracy score",ascending= False)
# Out:
#                  Model  Accuracy score
# 3        Random Forest        0.910355
# 4   Tune Random Forest        0.905324
# 1        Decision Tree        0.890048
# 2   Tune Decision Tree        0.838671
# 0  Logistic Regression        0.679839
# 6          Naive Bayes        0.585254
# 7                  KNN        0.585254
# 5                  SVM        0.521771
